# %%
# %pip install ultralytics opencv-python pyyaml

# %% [markdown]
# ## Vision inferencing with a local model
#
# In the first exercise, we can test out a basic [computer vision](https://www.microsoft.com/en-us/research/research-area/computer-vision/?msockid=22ee1fda33f46de00ef10b8532d86c89) inferencing task using a popular AI model called [YOLOv8](https://docs.ultralytics.com/models/yolov8/).
#
# To get started we will initialize the model via the Ultralytics python library. This will automatically download the model. Different sizes for the YOLOv8 model can be specified depending on the workload to adjust balance for accuracy versus speed. Once we initialize the model in our code, we can label the detected objects using [COCO dataset](https://cocodataset.org/#overview) class labels. The class labels dataset can be viewed [here](../artifacts/coco.yaml) where you can see the different types of objects that can be potentially identified.
#
# Click on the Play icon to the left of the cell below to initialize the model.

# %%
import cv2, yaml
from ultralytics import YOLO
from pprint import pprint 

model = YOLO('yolov8n.pt')  # You can use 'yolov8s.pt', 'yolov8m.pt', etc. for different model sizes

# This code loads the class names from the COCO dataset yaml file. 
def load_class_names(yaml_file):
    with open(yaml_file, 'r') as f:
        data = yaml.safe_load(f)
    return data['names']

class_names = load_class_names('../artifacts/coco.yaml')  # Adjust the path to your .names file

pprint(class_names)
# Out:
# {0: 'person',
#  1: 'bicycle',
#  2: 'car',
#  3: 'motorcycle',
#  4: 'airplane',
#  5: 'bus',
#  6: 'train',
#  7: 'truck',
#  8: 'boat',
#  9: 'traffic light',
#  10: 'fire hydrant',
#  11: 'stop sign',
#  12: 'parking meter',
#  13: 'bench',
#  14: 'bird',
#  15: 'cat',
#  16: 'dog',
#  17: 'horse',
#  18: 'sheep',
#  19: 'cow',
#  20: 'elephant',
#  21: 'bear',
#  22: 'zebra',
#  23: 'giraffe',
#  24: 'backpack',
#  25: 'umbrella',
#  26: 'handbag',
#  27: 'tie',
#  28: 'suitcase',
#  29: 'frisbee',
#  30: 'skis',
#  31: 'snowboard',
#  32: 'sports ball',
#  33: 'kite',
#  34: 'baseball bat',
#  35: 'baseball glove',
#  36: 'skateboard',
#  37: 'surfboard',
#  38: 'tennis racket',
#  39: 'bottle',
#  40: 'wine glass',
#  41: 'cup',
#  42: 'fork',
#  43: 'knife',
#  44: 'spoon',
#  45: 'bowl',
#  46: 'banana',
#  47: 'apple',
#  48: 'sandwich',
#  49: 'orange',
#  50: 'broccoli',
#  51: 'carrot',
#  52: 'hot dog',
#  53: 'pizza',
#  54: 'donut',
#  55: 'cake',
#  56: 'chair',
#  57: 'couch',
#  58: 'potted plant',
#  59: 'bed',
#  60: 'dining table',
#  61: 'toilet',
#  62: 'tv',
#  63: 'laptop',
#  64: 'mouse',
#  65: 'remote',
#  66: 'keyboard',
#  67: 'cell phone',
#  68: 'microwave',
#  69: 'oven',
#  70: 'toaster',
#  71: 'sink',
#  72: 'refrigerator',
#  73: 'book',
#  74: 'clock',
#  75: 'vase',
#  76: 'scissors',
#  77: 'teddy bear',
#  78: 'hair drier',
#  79: 'toothbrush'}

# %% [markdown]
# ### Basic object detection on a static image
#
# The next code block will load an image from disk using the Python [OpenCV](https://opencv.org/) library and send it to the model for basic object detection. Any detected objects will be annotated with a box drawn around them.

# %%
# Load image
image_path = '../media/image/people_on_street.jpg'
image = cv2.imread(image_path)

# Perform basic detection
results = model(image)

# Draw bounding boxes on the image and label objects by referencing the class names
for result in results:
    for box in result.boxes:
        class_id = int(box.cls[0])
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        confidence = box.conf[0]
        label = f'{class_names[class_id]} {confidence:.2f}'
        cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

# Save or display the image
#cv2.imwrite('output_image.jpg', image)
cv2.imshow('Press Q to close', image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 0: 448x640 10 persons, 2 handbags, 39.0ms
# Speed: 3.4ms preprocess, 39.0ms inference, 131.2ms postprocess per image at shape (1, 3, 448, 640)

# %% [markdown]
# ### YOLO with video
#
# Now let's try the same technique but this time using a live video.

# %%
# Load the YOLOv8 model
model = YOLO('yolov8n.pt')

# Load video
video_path = '../media/video/sample.mp4'
cap = cv2.VideoCapture(video_path)

delay = 1

# Get video writer initialized to save the output video
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('output_video.avi', fourcc, 20.0, (int(cap.get(3)), int(cap.get(4))))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Perform detection
    results = model(frame)

    # Draw bounding boxes on the frame
    for result in results:
        for box in result.boxes:
            class_id = int(box.cls[0])
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            confidence = box.conf[0]
            label = f'{class_names[class_id]} {confidence:.2f}'
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)


    # Write the frame into the output video
    out.write(frame)

    # Display the frame until q is pressed
    cv2.imshow('Detected People (press Q to exit)', frame)
    if cv2.waitKey(delay) & 0xFF == ord('q'): 
        break

cap.release()
out.release() 
cv2.destroyAllWindows()
# Out:
# 0: 384x640 6 persons, 65.2ms
# Speed: 3.8ms preprocess, 65.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 boat, 10.1ms
# Speed: 2.2ms preprocess, 10.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 boat, 5.4ms
# Speed: 1.4ms preprocess, 5.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 5.8ms
# Speed: 1.7ms preprocess, 5.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 11.7ms
# Speed: 2.7ms preprocess, 11.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 apple, 5.1ms
# Speed: 2.0ms preprocess, 5.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 apples, 5.3ms
# Speed: 1.5ms preprocess, 5.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 apples, 5.2ms
# Speed: 1.4ms preprocess, 5.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 5.2ms
# Speed: 1.7ms preprocess, 5.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 apples, 7.3ms
# Speed: 1.8ms preprocess, 7.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 apple, 5.1ms
# Speed: 1.7ms preprocess, 5.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 apple, 7.3ms
# Speed: 1.5ms preprocess, 7.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 apple, 5.2ms
# Speed: 1.7ms preprocess, 5.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 5.1ms
# Speed: 1.7ms preprocess, 5.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 9.9ms
# Speed: 1.7ms preprocess, 9.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 9.9ms
# Speed: 1.9ms preprocess, 9.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 motorcycle, 10.3ms
# Speed: 1.9ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 backpacks, 1 apple, 11.9ms
# Speed: 1.8ms preprocess, 11.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 backpacks, 2 apples, 11.2ms
# Speed: 2.1ms preprocess, 11.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 backpacks, 1 apple, 11.6ms
# Speed: 2.6ms preprocess, 11.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 motorcycle, 3 backpacks, 12.4ms
# Speed: 1.9ms preprocess, 12.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 truck, 1 boat, 1 backpack, 12.2ms
# Speed: 1.8ms preprocess, 12.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 boat, 1 backpack, 1 skateboard, 12.8ms
# Speed: 1.9ms preprocess, 12.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 truck, 1 backpack, 2 skateboards, 13.8ms
# Speed: 2.3ms preprocess, 13.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 truck, 1 backpack, 1 skateboard, 14.7ms
# Speed: 2.2ms preprocess, 14.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 2 backpacks, 14.7ms
# Speed: 2.2ms preprocess, 14.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 backpacks, 1 snowboard, 15.5ms
# Speed: 1.9ms preprocess, 15.5ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 backpacks, 1 snowboard, 16.3ms
# Speed: 2.1ms preprocess, 16.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 backpacks, 16.2ms
# Speed: 1.8ms preprocess, 16.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 2 backpacks, 17.2ms
# Speed: 1.8ms preprocess, 17.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 2 backpacks, 18.4ms
# Speed: 2.5ms preprocess, 18.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 backpacks, 18.4ms
# Speed: 2.5ms preprocess, 18.4ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 backpacks, 18.3ms
# Speed: 2.1ms preprocess, 18.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 backpack, 18.4ms
# Speed: 2.3ms preprocess, 18.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 truck, 2 backpacks, 33.4ms
# Speed: 3.3ms preprocess, 33.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 truck, 1 backpack, 33.3ms
# Speed: 3.2ms preprocess, 33.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 backpack, 33.4ms
# Speed: 3.2ms preprocess, 33.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 truck, 1 backpack, 33.6ms
# Speed: 3.2ms preprocess, 33.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)

# %%
# Load the YOLOv8 model
model = YOLO('yolov8n.pt')

# Load video
video_path = 'rtsp://admin:Passw0rd123!!@192.168.2.245:554/cam/realmonitor?channel=1&subtype=0'
cap = cv2.VideoCapture(video_path)

# Get video writer initialized to save the output video
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('output_video.avi', fourcc, 20.0, (int(cap.get(3)), int(cap.get(4))))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Perform detection
    results = model(frame)

    # Draw bounding boxes on the frame
    for result in results:
        for box in result.boxes:
            class_id = int(box.cls[0])
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            confidence = box.conf[0]
            label = f'{class_names[class_id]} {confidence:.2f}'
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)


    # Write the frame into the output video
    out.write(frame)

    # Display the frame until q is pressed
    cv2.imshow('Detected People (press Q to exit)', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'): 
        break

cap.release()
out.release() 
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 person, 1 suitcase, 1 tv, 1 laptop, 21.5ms
# Speed: 5.0ms preprocess, 21.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 tv, 6.1ms
# Speed: 1.9ms preprocess, 6.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 tv, 11.7ms
# Speed: 1.5ms preprocess, 11.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 tv, 11.6ms
# Speed: 1.8ms preprocess, 11.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 tv, 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 tv, 6.1ms
# Speed: 1.5ms preprocess, 6.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 tv, 6.2ms
# Speed: 1.8ms preprocess, 6.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 tv, 1 laptop, 7.3ms
# Speed: 1.6ms preprocess, 7.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 tv, 1 laptop, 12.4ms
# Speed: 3.4ms preprocess, 12.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 tv, 1 laptop, 7.6ms
# Speed: 1.7ms preprocess, 7.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 6.5ms
# Speed: 2.0ms preprocess, 6.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 5.8ms
# Speed: 1.4ms preprocess, 5.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 suitcases, 5.5ms
# Speed: 1.5ms preprocess, 5.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 suitcase, 5.7ms
# Speed: 1.4ms preprocess, 5.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 suitcase, 1 tv, 5.4ms
# Speed: 1.5ms preprocess, 5.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 suitcase, 2 tvs, 6.0ms
# Speed: 1.5ms preprocess, 6.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 tv, 7.8ms
# Speed: 1.8ms preprocess, 7.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 2 tvs, 5.6ms
# Speed: 1.5ms preprocess, 5.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 2 tvs, 8.0ms
# Speed: 1.6ms preprocess, 8.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 2 tvs, 5.2ms
# Speed: 1.5ms preprocess, 5.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 2 tvs, 5.9ms
# Speed: 1.6ms preprocess, 5.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 2 tvs, 1 laptop, 5.2ms
# Speed: 1.5ms preprocess, 5.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 2 tvs, 1 laptop, 6.0ms
# Speed: 1.4ms preprocess, 6.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 tv, 1 laptop, 9.6ms
# Speed: 1.8ms preprocess, 9.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 2 tvs, 1 laptop, 7.5ms
# Speed: 1.6ms preprocess, 7.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 tv, 7.3ms
# Speed: 1.5ms preprocess, 7.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 2 tvs, 5.9ms
# Speed: 1.4ms preprocess, 5.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 2 tvs, 5.8ms
# Speed: 2.0ms preprocess, 5.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 2 tvs, 6.2ms
# Speed: 2.8ms preprocess, 6.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 2 tvs, 5.9ms
# Speed: 1.5ms preprocess, 5.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 suitcase, 2 tvs, 6.3ms
# Speed: 1.5ms preprocess, 6.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 2 tvs, 6.3ms
# Speed: 1.5ms preprocess, 6.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 2 tvs, 6.9ms
# Speed: 1.7ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 tvs, 6.4ms
# Speed: 1.9ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 tvs, 6.2ms
# Speed: 1.7ms preprocess, 6.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 2 tvs, 6.4ms
# Speed: 1.5ms preprocess, 6.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 suitcase, 2 tvs, 6.3ms
# Speed: 1.7ms preprocess, 6.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 2 tvs, 5.5ms
# Speed: 1.6ms preprocess, 5.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 tvs, 5.7ms
# Speed: 1.8ms preprocess, 5.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 tvs, 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 tvs, 7.8ms
# Speed: 1.7ms preprocess, 7.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 tvs, 7.9ms
# Speed: 1.7ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 tvs, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 tvs, 11.4ms
# Speed: 2.0ms preprocess, 11.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 tvs, 7.8ms
# Speed: 1.7ms preprocess, 7.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 tvs, 13.6ms
# Speed: 1.7ms preprocess, 13.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 tvs, 7.8ms
# Speed: 1.7ms preprocess, 7.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 tvs, 7.9ms
# Speed: 1.6ms preprocess, 7.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 tvs, 8.3ms
# Speed: 1.7ms preprocess, 8.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 tv, 10.7ms
# Speed: 2.0ms preprocess, 10.7ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.1ms
# Speed: 1.7ms preprocess, 8.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.8ms
# Speed: 1.6ms preprocess, 8.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.7ms
# Speed: 1.7ms preprocess, 8.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.5ms
# Speed: 2.7ms preprocess, 8.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.9ms
# Speed: 2.0ms preprocess, 8.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13.6ms
# Speed: 3.1ms preprocess, 13.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.4ms
# Speed: 1.7ms preprocess, 8.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.3ms
# Speed: 1.6ms preprocess, 8.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.3ms
# Speed: 1.8ms preprocess, 8.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.4ms
# Speed: 2.0ms preprocess, 8.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 8.4ms
# Speed: 2.1ms preprocess, 8.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 8.6ms
# Speed: 1.7ms preprocess, 8.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 tv, 8.6ms
# Speed: 3.1ms preprocess, 8.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 8.5ms
# Speed: 1.7ms preprocess, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 tv, 12.7ms
# Speed: 2.3ms preprocess, 12.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 8.9ms
# Speed: 1.9ms preprocess, 8.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 tv, 13.5ms
# Speed: 3.4ms preprocess, 13.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 11.3ms
# Speed: 1.9ms preprocess, 11.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 8.9ms
# Speed: 1.7ms preprocess, 8.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 9.2ms
# Speed: 2.4ms preprocess, 9.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 10.0ms
# Speed: 1.9ms preprocess, 10.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 9.2ms
# Speed: 2.1ms preprocess, 9.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 9.8ms
# Speed: 1.8ms preprocess, 9.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 9.7ms
# Speed: 2.0ms preprocess, 9.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 9.5ms
# Speed: 2.1ms preprocess, 9.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 10.5ms
# Speed: 1.8ms preprocess, 10.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 tv, 1 laptop, 9.4ms
# Speed: 2.3ms preprocess, 9.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 laptop, 9.3ms
# Speed: 1.6ms preprocess, 9.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 laptop, 9.8ms
# Speed: 1.6ms preprocess, 9.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 laptop, 9.5ms
# Speed: 1.9ms preprocess, 9.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 laptop, 9.7ms
# Speed: 2.0ms preprocess, 9.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 laptop, 9.6ms
# Speed: 1.6ms preprocess, 9.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 laptop, 9.8ms
# Speed: 1.9ms preprocess, 9.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 laptop, 9.8ms
# Speed: 2.1ms preprocess, 9.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 laptop, 9.7ms
# Speed: 1.7ms preprocess, 9.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 laptop, 9.9ms
# Speed: 2.4ms preprocess, 9.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 laptop, 9.8ms
# Speed: 2.0ms preprocess, 9.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 laptop, 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 laptop, 10.1ms
# Speed: 2.5ms preprocess, 10.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 laptop, 10.2ms
# Speed: 1.9ms preprocess, 10.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 laptop, 10.3ms
# Speed: 2.3ms preprocess, 10.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 laptop, 10.0ms
# Speed: 1.7ms preprocess, 10.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 laptop, 10.3ms
# Speed: 2.0ms preprocess, 10.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 laptop, 10.3ms
# Speed: 1.6ms preprocess, 10.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 10.3ms
# Speed: 2.5ms preprocess, 10.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 10.5ms
# Speed: 1.9ms preprocess, 10.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.7ms
# Speed: 2.1ms preprocess, 10.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 10.8ms
# Speed: 1.8ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 laptop, 10.7ms
# Speed: 1.9ms preprocess, 10.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 laptop, 10.6ms
# Speed: 1.7ms preprocess, 10.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 10.8ms
# Speed: 1.9ms preprocess, 10.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 laptop, 10.8ms
# Speed: 2.9ms preprocess, 10.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 10.8ms
# Speed: 1.8ms preprocess, 10.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 11.0ms
# Speed: 2.4ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 11.4ms
# Speed: 2.2ms preprocess, 11.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 11.2ms
# Speed: 1.7ms preprocess, 11.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 laptop, 11.3ms
# Speed: 1.8ms preprocess, 11.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 laptop, 11.2ms
# Speed: 1.8ms preprocess, 11.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 11.4ms
# Speed: 1.6ms preprocess, 11.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 11.5ms
# Speed: 1.8ms preprocess, 11.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 11.4ms
# Speed: 2.0ms preprocess, 11.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 11.5ms
# Speed: 1.8ms preprocess, 11.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 11.6ms
# Speed: 1.7ms preprocess, 11.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 11.5ms
# Speed: 2.4ms preprocess, 11.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 11.6ms
# Speed: 2.0ms preprocess, 11.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 11.5ms
# Speed: 1.8ms preprocess, 11.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 12.6ms
# Speed: 1.9ms preprocess, 12.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 11.8ms
# Speed: 1.9ms preprocess, 11.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 11.8ms
# Speed: 2.0ms preprocess, 11.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 laptop, 11.9ms
# Speed: 1.8ms preprocess, 11.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 11.9ms
# Speed: 1.7ms preprocess, 11.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 laptop, 11.8ms
# Speed: 1.7ms preprocess, 11.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 laptop, 11.9ms
# Speed: 1.7ms preprocess, 11.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 laptop, 12.1ms
# Speed: 1.7ms preprocess, 12.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 laptop, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 laptop, 11.9ms
# Speed: 2.1ms preprocess, 11.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 laptop, 12.0ms
# Speed: 1.9ms preprocess, 12.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 laptop, 12.3ms
# Speed: 1.9ms preprocess, 12.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 12.3ms
# Speed: 2.3ms preprocess, 12.3ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 laptop, 12.4ms
# Speed: 2.3ms preprocess, 12.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 12.3ms
# Speed: 2.0ms preprocess, 12.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 12.4ms
# Speed: 1.7ms preprocess, 12.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 laptop, 12.4ms
# Speed: 2.0ms preprocess, 12.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 laptop, 12.4ms
# Speed: 1.9ms preprocess, 12.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 suitcase, 1 tv, 12.4ms
# Speed: 2.2ms preprocess, 12.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 12.7ms
# Speed: 2.0ms preprocess, 12.7ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 tv, 12.7ms
# Speed: 1.7ms preprocess, 12.7ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 suitcase, 1 tv, 12.8ms
# Speed: 1.8ms preprocess, 12.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 tv, 12.8ms
# Speed: 1.8ms preprocess, 12.8ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 chair, 1 tv, 13.8ms
# Speed: 1.8ms preprocess, 13.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 chair, 1 tv, 1 laptop, 13.0ms
# Speed: 1.8ms preprocess, 13.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 chair, 1 tv, 1 laptop, 12.8ms
# Speed: 1.8ms preprocess, 12.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 1 tv, 12.9ms
# Speed: 1.8ms preprocess, 12.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 1 tv, 1 laptop, 12.9ms
# Speed: 2.5ms preprocess, 12.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 1 tv, 1 laptop, 15.0ms
# Speed: 1.8ms preprocess, 15.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 1 tv, 1 laptop, 13.2ms
# Speed: 2.0ms preprocess, 13.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 1 tv, 1 laptop, 13.2ms
# Speed: 1.9ms preprocess, 13.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 1 tv, 1 laptop, 13.3ms
# Speed: 1.9ms preprocess, 13.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 1 tv, 1 laptop, 13.3ms
# Speed: 2.4ms preprocess, 13.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 1 tv, 1 laptop, 13.3ms
# Speed: 1.7ms preprocess, 13.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 1 tv, 1 laptop, 13.6ms
# Speed: 1.9ms preprocess, 13.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 1 tv, 1 laptop, 13.5ms
# Speed: 2.0ms preprocess, 13.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 1 tv, 1 laptop, 13.4ms
# Speed: 1.7ms preprocess, 13.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 1 laptop, 13.4ms
# Speed: 1.7ms preprocess, 13.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 1 tv, 1 laptop, 13.4ms
# Speed: 1.9ms preprocess, 13.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 1 tv, 1 laptop, 13.4ms
# Speed: 1.9ms preprocess, 13.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 1 tv, 1 laptop, 13.4ms
# Speed: 1.9ms preprocess, 13.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 1 tv, 1 laptop, 13.5ms
# Speed: 1.9ms preprocess, 13.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 1 tv, 1 laptop, 13.9ms
# Speed: 1.7ms preprocess, 13.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 chair, 1 tv, 1 laptop, 13.8ms
# Speed: 1.7ms preprocess, 13.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 chair, 1 tv, 1 laptop, 13.9ms
# Speed: 1.9ms preprocess, 13.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 chair, 1 tv, 1 laptop, 13.8ms
# Speed: 1.9ms preprocess, 13.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 chair, 1 tv, 1 laptop, 14.3ms
# Speed: 1.7ms preprocess, 14.3ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 chair, 1 tv, 1 laptop, 14.0ms
# Speed: 1.8ms preprocess, 14.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 chair, 1 tv, 1 laptop, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 chair, 1 tv, 1 laptop, 14.0ms
# Speed: 1.7ms preprocess, 14.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 chair, 1 tv, 1 laptop, 14.2ms
# Speed: 2.5ms preprocess, 14.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 chair, 1 tv, 1 laptop, 14.2ms
# Speed: 2.0ms preprocess, 14.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 chair, 1 tv, 1 laptop, 14.1ms
# Speed: 2.0ms preprocess, 14.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 chair, 1 tv, 1 laptop, 14.0ms
# Speed: 2.1ms preprocess, 14.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 chair, 1 tv, 1 laptop, 14.1ms
# Speed: 1.9ms preprocess, 14.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 chair, 1 tv, 1 laptop, 14.1ms
# Speed: 2.0ms preprocess, 14.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 chair, 1 tv, 1 laptop, 14.0ms
# Speed: 2.1ms preprocess, 14.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 chair, 1 tv, 1 laptop, 14.0ms
# Speed: 1.9ms preprocess, 14.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 chair, 1 tv, 1 laptop, 14.1ms
# Speed: 1.7ms preprocess, 14.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 chair, 1 tv, 1 laptop, 14.2ms
# Speed: 1.8ms preprocess, 14.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 tv, 1 laptop, 14.5ms
# Speed: 1.8ms preprocess, 14.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 chair, 1 tv, 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 chair, 1 tv, 14.4ms
# Speed: 1.8ms preprocess, 14.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 chair, 1 tv, 14.5ms
# Speed: 1.7ms preprocess, 14.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 chair, 1 tv, 14.4ms
# Speed: 1.9ms preprocess, 14.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 chair, 1 tv, 15.7ms
# Speed: 1.8ms preprocess, 15.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 chair, 1 tv, 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 chair, 1 tv, 14.7ms
# Speed: 1.9ms preprocess, 14.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 tv, 14.7ms
# Speed: 1.9ms preprocess, 14.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 tv, 15.9ms
# Speed: 1.8ms preprocess, 15.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 tv, 14.6ms
# Speed: 1.8ms preprocess, 14.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 tv, 14.8ms
# Speed: 2.0ms preprocess, 14.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 tv, 14.6ms
# Speed: 1.8ms preprocess, 14.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 tv, 14.7ms
# Speed: 2.0ms preprocess, 14.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 tv, 14.6ms
# Speed: 1.9ms preprocess, 14.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 tv, 14.7ms
# Speed: 2.2ms preprocess, 14.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 tv, 15.3ms
# Speed: 1.9ms preprocess, 15.3ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 tv, 15.2ms
# Speed: 2.3ms preprocess, 15.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 tv, 15.2ms
# Speed: 2.2ms preprocess, 15.2ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 tv, 15.2ms
# Speed: 2.0ms preprocess, 15.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 tv, 1 laptop, 15.4ms
# Speed: 1.7ms preprocess, 15.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 tv, 1 laptop, 15.4ms
# Speed: 1.9ms preprocess, 15.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 tv, 1 laptop, 15.4ms
# Speed: 2.0ms preprocess, 15.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 tv, 1 laptop, 15.4ms
# Speed: 1.8ms preprocess, 15.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 tv, 1 laptop, 15.4ms
# Speed: 2.1ms preprocess, 15.4ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 tv, 1 laptop, 1 oven, 15.3ms
# Speed: 1.8ms preprocess, 15.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 tv, 1 laptop, 15.6ms
# Speed: 2.6ms preprocess, 15.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 tv, 1 laptop, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 tv, 1 laptop, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 tv, 16.1ms
# Speed: 2.1ms preprocess, 16.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 tv, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 tv, 16.0ms
# Speed: 2.1ms preprocess, 16.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 16.0ms
# Speed: 1.9ms preprocess, 16.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 tv, 16.2ms
# Speed: 2.2ms preprocess, 16.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 tv, 1 laptop, 16.3ms
# Speed: 2.3ms preprocess, 16.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 laptop, 16.0ms
# Speed: 2.9ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 laptop, 16.1ms
# Speed: 2.4ms preprocess, 16.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 16.0ms
# Speed: 1.9ms preprocess, 16.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16.1ms
# Speed: 1.9ms preprocess, 16.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16.0ms
# Speed: 2.2ms preprocess, 16.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 laptop, 16.3ms
# Speed: 2.1ms preprocess, 16.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 16.3ms
# Speed: 1.9ms preprocess, 16.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 16.2ms
# Speed: 2.1ms preprocess, 16.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 16.2ms
# Speed: 1.8ms preprocess, 16.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 16.3ms
# Speed: 2.0ms preprocess, 16.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 16.3ms
# Speed: 2.0ms preprocess, 16.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16.9ms
# Speed: 1.9ms preprocess, 16.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16.3ms
# Speed: 2.1ms preprocess, 16.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 16.3ms
# Speed: 2.0ms preprocess, 16.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 16.3ms
# Speed: 2.0ms preprocess, 16.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 16.3ms
# Speed: 2.0ms preprocess, 16.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 tv, 16.5ms
# Speed: 1.9ms preprocess, 16.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 16.3ms
# Speed: 2.2ms preprocess, 16.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 16.3ms
# Speed: 2.0ms preprocess, 16.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 16.4ms
# Speed: 1.9ms preprocess, 16.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16.3ms
# Speed: 1.9ms preprocess, 16.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16.2ms
# Speed: 1.7ms preprocess, 16.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16.1ms
# Speed: 2.2ms preprocess, 16.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16.0ms
# Speed: 1.8ms preprocess, 16.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16.0ms
# Speed: 2.1ms preprocess, 16.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16.0ms
# Speed: 1.9ms preprocess, 16.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16.1ms
# Speed: 2.2ms preprocess, 16.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16.0ms
# Speed: 2.1ms preprocess, 16.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 16.1ms
# Speed: 2.3ms preprocess, 16.1ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16.0ms
# Speed: 1.8ms preprocess, 16.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16.1ms
# Speed: 2.1ms preprocess, 16.1ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16.0ms
# Speed: 1.8ms preprocess, 16.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16.2ms
# Speed: 2.2ms preprocess, 16.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 16.1ms
# Speed: 1.8ms preprocess, 16.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 16.1ms
# Speed: 2.1ms preprocess, 16.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16.0ms
# Speed: 1.9ms preprocess, 16.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 19.2ms
# Speed: 1.9ms preprocess, 19.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16.1ms
# Speed: 2.2ms preprocess, 16.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16.1ms
# Speed: 1.9ms preprocess, 16.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16.1ms
# Speed: 2.2ms preprocess, 16.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16.0ms
# Speed: 1.8ms preprocess, 16.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 book, 16.1ms
# Speed: 1.9ms preprocess, 16.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16.1ms
# Speed: 1.8ms preprocess, 16.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16.1ms
# Speed: 2.3ms preprocess, 16.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16.1ms
# Speed: 1.9ms preprocess, 16.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16.3ms
# Speed: 2.3ms preprocess, 16.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16.0ms
# Speed: 2.3ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16.0ms
# Speed: 1.8ms preprocess, 16.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16.2ms
# Speed: 1.9ms preprocess, 16.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.0ms
# Speed: 1.9ms preprocess, 16.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16.1ms
# Speed: 2.4ms preprocess, 16.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 16.0ms
# Speed: 1.8ms preprocess, 16.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 16.1ms
# Speed: 2.1ms preprocess, 16.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 16.1ms
# Speed: 1.8ms preprocess, 16.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 16.0ms
# Speed: 1.9ms preprocess, 16.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 16.7ms
# Speed: 1.9ms preprocess, 16.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.4ms
# Speed: 2.0ms preprocess, 17.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.4ms
# Speed: 2.0ms preprocess, 17.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 mouse, 17.3ms
# Speed: 1.9ms preprocess, 17.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 mouse, 17.2ms
# Speed: 2.1ms preprocess, 17.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 1 mouse, 17.3ms
# Speed: 2.0ms preprocess, 17.3ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 tv, 17.3ms
# Speed: 2.3ms preprocess, 17.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 17.4ms
# Speed: 2.2ms preprocess, 17.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 1 mouse, 17.2ms
# Speed: 1.8ms preprocess, 17.2ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 1 mouse, 17.2ms
# Speed: 1.9ms preprocess, 17.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 17.4ms
# Speed: 2.0ms preprocess, 17.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 1 keyboard, 17.3ms
# Speed: 1.9ms preprocess, 17.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 mouse, 1 keyboard, 18.0ms
# Speed: 1.7ms preprocess, 18.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 18.1ms
# Speed: 2.5ms preprocess, 18.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 mouse, 18.1ms
# Speed: 1.9ms preprocess, 18.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 18.1ms
# Speed: 1.9ms preprocess, 18.1ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 1 keyboard, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 mouse, 18.0ms
# Speed: 1.8ms preprocess, 18.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 1 mouse, 21.1ms
# Speed: 2.0ms preprocess, 21.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 mouse, 18.0ms
# Speed: 2.1ms preprocess, 18.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 mouse, 18.0ms
# Speed: 2.1ms preprocess, 18.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 mouse, 18.2ms
# Speed: 2.2ms preprocess, 18.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 mouse, 18.2ms
# Speed: 2.2ms preprocess, 18.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 18.1ms
# Speed: 2.0ms preprocess, 18.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 18.0ms
# Speed: 1.8ms preprocess, 18.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 18.0ms
# Speed: 1.9ms preprocess, 18.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 18.0ms
# Speed: 1.9ms preprocess, 18.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 keyboard, 18.2ms
# Speed: 2.9ms preprocess, 18.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 keyboard, 18.0ms
# Speed: 1.8ms preprocess, 18.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 keyboard, 18.0ms
# Speed: 1.8ms preprocess, 18.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 keyboard, 18.1ms
# Speed: 2.0ms preprocess, 18.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 keyboard, 18.4ms
# Speed: 2.1ms preprocess, 18.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 18.2ms
# Speed: 1.8ms preprocess, 18.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 1 keyboard, 18.2ms
# Speed: 2.7ms preprocess, 18.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 keyboard, 17.2ms
# Speed: 1.8ms preprocess, 17.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 keyboard, 17.3ms
# Speed: 2.1ms preprocess, 17.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 mouse, 1 keyboard, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 mouse, 1 keyboard, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 mouse, 1 keyboard, 17.2ms
# Speed: 1.9ms preprocess, 17.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 mouse, 17.3ms
# Speed: 2.0ms preprocess, 17.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 17.3ms
# Speed: 2.0ms preprocess, 17.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 keyboard, 17.3ms
# Speed: 2.1ms preprocess, 17.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 1 keyboard, 17.4ms
# Speed: 1.9ms preprocess, 17.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 keyboard, 17.3ms
# Speed: 1.9ms preprocess, 17.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 17.3ms
# Speed: 1.9ms preprocess, 17.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 1 keyboard, 17.3ms
# Speed: 1.9ms preprocess, 17.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 1 mouse, 1 keyboard, 17.3ms
# Speed: 2.0ms preprocess, 17.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 1 mouse, 1 keyboard, 17.3ms
# Speed: 1.9ms preprocess, 17.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 keyboard, 17.3ms
# Speed: 1.9ms preprocess, 17.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 keyboard, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 keyboard, 17.3ms
# Speed: 2.0ms preprocess, 17.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 1 keyboard, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 keyboard, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 mouse, 1 keyboard, 17.0ms
# Speed: 2.5ms preprocess, 17.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 mouse, 1 keyboard, 17.1ms
# Speed: 2.0ms preprocess, 17.1ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 mouse, 1 keyboard, 17.0ms
# Speed: 1.9ms preprocess, 17.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 mouse, 1 keyboard, 17.0ms
# Speed: 1.8ms preprocess, 17.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 mouse, 1 keyboard, 17.0ms
# Speed: 1.9ms preprocess, 17.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 mouse, 1 keyboard, 17.0ms
# Speed: 2.1ms preprocess, 17.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 mouse, 1 keyboard, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 mouse, 1 keyboard, 17.8ms
# Speed: 1.9ms preprocess, 17.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 mouse, 1 keyboard, 17.0ms
# Speed: 1.8ms preprocess, 17.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 mouse, 1 keyboard, 17.1ms
# Speed: 2.1ms preprocess, 17.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 mouse, 1 keyboard, 17.0ms
# Speed: 1.8ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 tvs, 1 mouse, 1 keyboard, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 1 mouse, 1 keyboard, 17.4ms
# Speed: 2.0ms preprocess, 17.4ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 2 tvs, 1 mouse, 1 keyboard, 17.0ms
# Speed: 2.1ms preprocess, 17.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 1 mouse, 1 keyboard, 17.1ms
# Speed: 1.9ms preprocess, 17.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 chair, 2 tvs, 1 mouse, 1 keyboard, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 chair, 2 tvs, 1 laptop, 1 mouse, 1 keyboard, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 chair, 2 tvs, 1 mouse, 1 keyboard, 17.2ms
# Speed: 2.1ms preprocess, 17.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 2 tvs, 1 mouse, 1 keyboard, 17.1ms
# Speed: 2.0ms preprocess, 17.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 tvs, 1 mouse, 1 keyboard, 17.0ms
# Speed: 1.8ms preprocess, 17.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 tvs, 1 mouse, 1 keyboard, 17.0ms
# ...
#
# 0: 384x640 2 persons, 1 bottle, 1 cup, 1 remote, 1 keyboard, 18.4ms
# Speed: 2.0ms preprocess, 18.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 2 remotes, 1 keyboard, 18.4ms
# Speed: 2.2ms preprocess, 18.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 1 remote, 1 keyboard, 18.3ms
# Speed: 2.0ms preprocess, 18.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 1 remote, 1 keyboard, 18.4ms
# Speed: 2.1ms preprocess, 18.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 1 remote, 1 keyboard, 18.5ms
# Speed: 2.0ms preprocess, 18.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 1 remote, 1 keyboard, 18.3ms
# Speed: 1.8ms preprocess, 18.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 2 remotes, 18.3ms
# Speed: 2.5ms preprocess, 18.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 2 remotes, 18.3ms
# Speed: 2.0ms preprocess, 18.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 2 remotes, 1 keyboard, 18.4ms
# Speed: 1.8ms preprocess, 18.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 1 remote, 1 keyboard, 18.4ms
# Speed: 1.9ms preprocess, 18.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 1 remote, 1 keyboard, 18.3ms
# Speed: 2.3ms preprocess, 18.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 2 remotes, 1 keyboard, 18.4ms
# Speed: 1.9ms preprocess, 18.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 1 remote, 1 keyboard, 18.3ms
# Speed: 2.1ms preprocess, 18.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 1 remote, 1 keyboard, 18.4ms
# Speed: 1.8ms preprocess, 18.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 1 remote, 1 keyboard, 18.1ms
# Speed: 1.9ms preprocess, 18.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 1 tv, 1 remote, 1 keyboard, 18.2ms
# Speed: 2.6ms preprocess, 18.2ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 1 tv, 1 remote, 1 keyboard, 18.1ms
# Speed: 2.0ms preprocess, 18.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 1 remote, 1 keyboard, 18.1ms
# Speed: 2.0ms preprocess, 18.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 1 remote, 1 keyboard, 18.1ms
# Speed: 2.1ms preprocess, 18.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 1 remote, 1 keyboard, 18.1ms
# Speed: 2.2ms preprocess, 18.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 1 remote, 1 keyboard, 18.2ms
# Speed: 2.6ms preprocess, 18.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 1 tv, 1 remote, 1 keyboard, 18.1ms
# Speed: 2.1ms preprocess, 18.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 1 remote, 1 keyboard, 18.2ms
# Speed: 2.0ms preprocess, 18.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 18.2ms
# Speed: 2.2ms preprocess, 18.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 1 remote, 1 keyboard, 18.1ms
# Speed: 2.0ms preprocess, 18.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 18.2ms
# Speed: 2.2ms preprocess, 18.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 1 remote, 1 keyboard, 18.0ms
# Speed: 1.9ms preprocess, 18.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 18.0ms
# Speed: 2.1ms preprocess, 18.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 18.1ms
# Speed: 2.0ms preprocess, 18.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 tv, 1 remote, 1 keyboard, 18.1ms
# Speed: 2.0ms preprocess, 18.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 18.1ms
# Speed: 2.1ms preprocess, 18.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 1 remote, 1 keyboard, 18.1ms
# Speed: 1.9ms preprocess, 18.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 1 remote, 1 keyboard, 18.1ms
# Speed: 2.0ms preprocess, 18.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 17.2ms
# Speed: 1.7ms preprocess, 17.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 17.3ms
# Speed: 2.1ms preprocess, 17.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 17.3ms
# Speed: 2.3ms preprocess, 17.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 17.3ms
# Speed: 2.1ms preprocess, 17.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 17.2ms
# Speed: 1.9ms preprocess, 17.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 17.3ms
# Speed: 1.8ms preprocess, 17.3ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 17.4ms
# Speed: 2.5ms preprocess, 17.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 17.3ms
# Speed: 2.3ms preprocess, 17.3ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 17.3ms
# Speed: 1.9ms preprocess, 17.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 17.3ms
# Speed: 2.1ms preprocess, 17.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 17.5ms
# Speed: 2.0ms preprocess, 17.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 1 remote, 1 keyboard, 17.2ms
# Speed: 1.9ms preprocess, 17.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 17.3ms
# Speed: 2.3ms preprocess, 17.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 17.4ms
# Speed: 2.0ms preprocess, 17.4ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 1 remote, 1 keyboard, 17.3ms
# Speed: 1.9ms preprocess, 17.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 1 remote, 1 keyboard, 17.3ms
# Speed: 1.9ms preprocess, 17.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 17.2ms
# Speed: 1.9ms preprocess, 17.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 17.3ms
# Speed: 2.0ms preprocess, 17.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 17.7ms
# Speed: 2.3ms preprocess, 17.7ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 17.3ms
# Speed: 1.9ms preprocess, 17.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 17.4ms
# Speed: 2.2ms preprocess, 17.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 17.2ms
# Speed: 2.2ms preprocess, 17.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 17.3ms
# Speed: 2.2ms preprocess, 17.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 17.3ms
# Speed: 2.0ms preprocess, 17.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 17.3ms
# Speed: 1.9ms preprocess, 17.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 17.2ms
# Speed: 2.1ms preprocess, 17.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 17.3ms
# Speed: 2.3ms preprocess, 17.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 17.6ms
# Speed: 3.6ms preprocess, 17.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 17.3ms
# Speed: 2.2ms preprocess, 17.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 17.4ms
# Speed: 2.2ms preprocess, 17.4ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 17.4ms
# Speed: 2.2ms preprocess, 17.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 17.3ms
# Speed: 2.1ms preprocess, 17.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 18.9ms
# Speed: 2.1ms preprocess, 18.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 20.8ms
# Speed: 2.7ms preprocess, 20.8ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 18.1ms
# Speed: 2.2ms preprocess, 18.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 18.1ms
# Speed: 1.8ms preprocess, 18.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 18.1ms
# Speed: 2.1ms preprocess, 18.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 1 teddy bear, 18.1ms
# Speed: 1.9ms preprocess, 18.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 1 teddy bear, 18.1ms
# Speed: 2.4ms preprocess, 18.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 18.1ms
# Speed: 2.0ms preprocess, 18.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 18.1ms
# Speed: 2.2ms preprocess, 18.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 cup, 1 remote, 1 keyboard, 18.3ms
# Speed: 2.0ms preprocess, 18.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 1 remote, 1 keyboard, 18.0ms
# Speed: 2.2ms preprocess, 18.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 1 remote, 18.1ms
# Speed: 1.9ms preprocess, 18.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 1 remote, 18.1ms
# Speed: 1.9ms preprocess, 18.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 1 remote, 18.1ms
# Speed: 2.0ms preprocess, 18.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 1 remote, 18.1ms
# Speed: 2.2ms preprocess, 18.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 1 remote, 18.1ms
# Speed: 2.1ms preprocess, 18.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 1 remote, 18.2ms
# Speed: 2.6ms preprocess, 18.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 cup, 1 remote, 18.1ms
# Speed: 2.1ms preprocess, 18.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 1 remote, 18.1ms
# Speed: 2.0ms preprocess, 18.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 1 remote, 18.4ms
# Speed: 2.3ms preprocess, 18.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 1 remote, 18.0ms
# Speed: 2.1ms preprocess, 18.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 1 remote, 1 cell phone, 18.2ms
# Speed: 2.0ms preprocess, 18.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 1 remote, 1 cell phone, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 18.0ms
# Speed: 1.8ms preprocess, 18.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 18.2ms
# Speed: 2.0ms preprocess, 18.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 cup, 1 remote, 18.0ms
# Speed: 2.1ms preprocess, 18.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 cup, 1 remote, 18.1ms
# Speed: 2.0ms preprocess, 18.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 cup, 1 remote, 18.2ms
# Speed: 2.6ms preprocess, 18.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 remote, 18.3ms
# Speed: 2.2ms preprocess, 18.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 cup, 1 remote, 18.3ms
# Speed: 2.0ms preprocess, 18.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 cup, 1 remote, 1 keyboard, 18.4ms
# Speed: 2.4ms preprocess, 18.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 cup, 1 remote, 1 keyboard, 18.4ms
# Speed: 2.3ms preprocess, 18.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# ## Vision inferencing with Azure OpenAI and GPT4o

# %%
import os
import requests
import base64
from pprint import pprint

API_KEY = "xxxxxx"

encoded_image = base64.b64encode(open(IMAGE_PATH, 'rb').read()).decode('ascii')
headers = {
    "Content-Type": "application/json",
    "api-key": API_KEY,
}

# Payload for the request
payload = {
  "messages": [
    {
      "role": "system",
      "content": [
        {
          "type": "text",
          "text": "You are an AI assistant that helps people find information."
        }
      ]
    }
  ],
  "temperature": 0.7,
  "top_p": 0.95,
  "max_tokens": 800
}

ENDPOINT = "https://jsextoai.openai.azure.com/openai/deployments/gpt-4/chat/completions?api-version=2024-08-01-preview"

# Send request
try:
    response = requests.post(ENDPOINT, headers=headers, json=payload)
    response.raise_for_status()  # Will raise an HTTPError if the HTTP request returned an unsuccessful status code
except requests.RequestException as e:
    raise SystemExit(f"Failed to make the request. Error: {e}")

# Handle the response as needed (e.g., print or process)
response_json = response.json()
pprint(response_json)

# %%
import json
from pprint import pprint

def image_to_base64(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode('utf-8')


IMAGE_PATH = "./images/columns.png"
image_base64 = image_to_base64(IMAGE_PATH)
payload = {
  "messages": [
    { "role": "system", "content": "You are a helpful assistant." },
        { "role": "user", "content": [  
            { 
                "type": "text", 
                "text": "Describe this picture:" 
            },
            { 
                "type": "image_url",
                "image_url": {
                    "url": "data:image/png;base64," + image_base64
                }
            }
        ] } 
  ],
  "temperature": 0.7,
  "top_p": 0.95,
  "max_tokens": 800
}

response = requests.post(ENDPOINT, headers=headers, json=payload)
response_json = response.json()

# Pretty print the JSON response
pprint(response_json)
